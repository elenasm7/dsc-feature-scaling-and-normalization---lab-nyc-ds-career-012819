# %% [markdown]
# ## Feature Scaling and Normalization - Lab

# %% [markdown]
# ## Introduction
# In this lab, you'll practice your feature scaling and normalization skills!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Implement min-max scaling, mean-normalization, log normalization and unit vector normalization in python
# * Identify appropriate normalization and scaling techniques for given dataset

# %% [markdown]
# ## Back to our Boston Housing data

# %% [markdown]
# Let's import our Boston Housing data. Remember we categorized two variables and deleted the "NOX" (nitride oxide concentration) variable because it was highly correlated with two other features.

# %%
import pandas as pd
from sklearn.datasets import load_boston
boston = load_boston()

boston_features = pd.DataFrame(boston.data, columns = boston.feature_names)

# first, create bins for based on the values observed. 5 values will result in 4 bins
bins = [0, 3, 4 , 5, 24]
bins_rad = pd.cut(boston_features['RAD'], bins)
bins_rad = bins_rad.cat.as_unordered()

# first, create bins for based on the values observed. 5 values will result in 4 bins
bins = [0, 250, 300, 360, 460, 712]
bins_tax = pd.cut(boston_features['TAX'], bins)
bins_tax = bins_tax.cat.as_unordered()

tax_dummy = pd.get_dummies(bins_tax, prefix="TAX")
rad_dummy = pd.get_dummies(bins_rad, prefix="RAD")
boston_features = boston_features.drop(["RAD","TAX"], axis=1)
boston_features = pd.concat([boston_features, rad_dummy, tax_dummy], axis=1)
boston_features = boston_features.drop("NOX",axis=1)

# %% [markdown]
# ## Look at the histograms for the continuous variables

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

cont_features = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'RM', 'AGE', 'DIS', 'PTRATIO', 'B','LSTAT']
fig,axes = plt.subplots(nrows=2, ncols=5, figsize=(15,5))

for i in range(2):
    for j in range(5):
        k = sum([5 if i == 1 else 0])
        n = (k+j)
        sns.distplot(boston_features[cont_features[n]], ax=axes[i][j])
        fig.tight_layout()
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Perform log transformations for the variables where it makes sense

# %% [markdown]
# Analyze the results in terms of how they improved the normality performance. What is the problem with the "ZN" variable?

# %%
import numpy as np
import matplotlib.pyplot as plt

# for i in cont_features:
#     print(boston_features[i].isnull().sum())

log_cols = []
for i in cont_features:
    name = i+'_log'
    boston_features[name] = np.log(boston_features[i])
    log_cols.append(name)

del log_cols[1]
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.

# %%
# for i in log_cols:
#     print(boston_features[i].isnull().sum())
del log_cols[2]

# %%
# del log_cols[1]
# del log_cols[2]
fig,axes = plt.subplots(nrows=2, ncols=4, figsize=(15,7))

for i in range(2):
    for j in range(4):
        k = sum([4 if i == 1 else 0])
        n = (k+j)
        sns.distplot(boston_features[log_cols[n]], ax=axes[i][j])
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# "ZN" has a lot of zeros (more than 50%!). Remember that this variable denoted: "proportion of residential land zoned for lots over 25,000 sq.ft.". It might have made sense to categorize this variable to "over 25,000 feet or not (binary variable 1/0). Now you have a zero-inflated variable which is cumbersome to work with.

# %% [markdown]
# ## Try different types of transformations on the continuous variables

# %% [markdown]
# Store your final features in a dataframe `features_final`

# %%
features_final = pd.DataFrame()

def log_transform(cols, df,add_df=None,new_df=None):
    trans_cols = []
    for i in cols:
        name = i+'_log'
        trans_cols.append(name)
        if add_df != None:
            new_df[name] = np.log(df[i])
        else: 
            df[name] = np.log(df[i])
    return trans_cols
    
def cube_root_transform(cols, df,add_df=None,new_df=None):
    trans_cols = []
    for i in cols:
        name = i+'_cuberoot'
        trans_cols.append(name)
        if add_df != None:
            new_df[name] = df[i].apply(lambda x: x**(1/3))
        else: 
            df[name] = df[i].apply(lambda x: x**(1/3))
    return trans_cols

def sqrt_trandform(cols, df,add_df=None,new_df=None):
    trans_cols = []
    for i in cols:
        name = i+'_sqrt'
        trans_cols.append(name)
        if add_df != None:
            new_df[name] = df[i].apply(lambda x: x**(1/2))
        else: 
            df[name] = df[i].apply(lambda x: x**(1/2))
    return trans_cols

def sqre_trandform(cols, df,add_df=None,new_df=None):
    trans_cols = []
    for i in cols:
        name = i+'_squared'
        trans_cols.append(name)
        if add_df != None:
            new_df[name] = df[i].apply(lambda x: x**2)
        else: 
            df[name] = df[i].apply(lambda x: x**2)
    return trans_cols

def recip_trandform(cols, df,add_df=None,new_df=None):
    trans_cols = []
    for i in cols:
        name = i+'_recip'
        trans_cols.append(name)
        if add_df != None:
            new_df[name] = df[i].apply(lambda x: 1/x)
        else: 
            df[name] = df[i].apply(lambda x: 1/x)
    return trans_cols

# %%
# cont_features
cube_root_cols = cube_root_transform(cont_features, boston_features,True,features_final)

# %%
sqrt_cols = sqrt_trandform(cont_features, boston_features,True,features_final)

# %%
square_cols = sqre_trandform(cont_features, boston_features,True,features_final)

# %%
# recip_cols = recip_trandform(cont_features, boston_features,True,features_final)
for i in list(boston_features.columns):
    boston_fe
boston_features[]
# Out:
#          CRIM    ZN  INDUS  CHAS     RM    AGE     DIS  PTRATIO       B  \
# 0     0.00632  18.0   2.31   0.0  6.575   65.2  4.0900     15.3  396.90
# 1     0.02731   0.0   7.07   0.0  6.421   78.9  4.9671     17.8  396.90
# 2     0.02729   0.0   7.07   0.0  7.185   61.1  4.9671     17.8  392.83
# 3     0.03237   0.0   2.18   0.0  6.998   45.8  6.0622     18.7  394.63
# 4     0.06905   0.0   2.18   0.0  7.147   54.2  6.0622     18.7  396.90
# 5     0.02985   0.0   2.18   0.0  6.430   58.7  6.0622     18.7  394.12
# 6     0.08829  12.5   7.87   0.0  6.012   66.6  5.5605     15.2  395.60
# 7     0.14455  12.5   7.87   0.0  6.172   96.1  5.9505     15.2  396.90
# 8     0.21124  12.5   7.87   0.0  5.631  100.0  6.0821     15.2  386.63
# 9     0.17004  12.5   7.87   0.0  6.004   85.9  6.5921     15.2  386.71
# 10    0.22489  12.5   7.87   0.0  6.377   94.3  6.3467     15.2  392.52
# 11    0.11747  12.5   7.87   0.0  6.009   82.9  6.2267     15.2  396.90
# ...

# %%
log_columns = log_transform(log_cols, boston_features,True,features_final)
features_final
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in log
#   if __name__ == '__main__':
#      CRIM_log_log  INDUS_log_log  RM_log_log  AGE_log_log  DIS_log_log  \
# 0             NaN      -0.177636    0.633012     1.429703     0.342557
# 1             NaN       0.670830    0.620347     1.474347     0.471775
# 2             NaN       0.670830    0.679046     1.414034     0.471775
# 3             NaN      -0.249327    0.665583     1.341371     0.588938
# 4             NaN      -0.249327    0.676353     1.384463     0.588938
# 5             NaN      -0.249327    0.621100     1.404242     0.588938
# 6             NaN       0.724189    0.584313     1.434776     0.539814
# 7             NaN       0.724189    0.598849     1.518504     0.578564
# 8             NaN       0.724189    0.547131     1.527180     0.590754
# 9             NaN       0.724189    0.583570     1.493619     0.634390
# ...

# %%
features_final.head()
# Out:
#    CRIM_log_log  INDUS_log_log  RM_log_log  AGE_log_log  DIS_log_log  \
# 0           NaN      -0.177636    0.633012     1.429703     0.342557
# 1           NaN       0.670830    0.620347     1.474347     0.471775
# 2           NaN       0.670830    0.679046     1.414034     0.471775
# 3           NaN      -0.249327    0.665583     1.341371     0.588938
# 4           NaN      -0.249327    0.676353     1.384463     0.588938
#
#    PTRATIO_log_log  B_log_log  LSTAT_log_log  CRIM_cuberoot  ZN_cuberoot  \
# 0         1.003515   1.789036       0.473392       0.184887     2.620741
# 1         1.057512   1.789036       0.794196       0.301144     0.000000
# 2         1.057512   1.787312       0.332010       0.301070     0.000000
# 3         1.074498   1.788077       0.075487       0.318699     0.000000
# 4         1.074498   1.789036       0.514828       0.410256     0.000000
#
#        ...        CRIM_squared  ZN_squared  INDUS_squared  CHAS_squared  \
# ...

# %% [markdown]
# ## Summary
# Great! You've now transformed your final data using feature scaling and normalization, and stored them in the `features_final` dataframe.
